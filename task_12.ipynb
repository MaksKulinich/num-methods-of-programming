# %%
# Кулініч Максим
# Варіант 14

import numpy as np 
import matplotlib.pyplot as plt  

def f(x, y): 
    return x + np.sin(y/np.sqrt(7))

a = 0.5 # ліва межа відрізку 
b = 1.5 # права межа відрізку 
h = 0.1 # крок 
y0 = 0.6 # початкова умова
n = int((b - a) / h) # кількість кроків 

x = np.linspace(a, b, n+1) # задаємо x 
y = np.zeros(n+1)
y[0] = y0 

for i in range(n): 
    y[i+1] = y[i] + f(x[i], y[i]) * h 

print("x =", x, "\ny =", y)

plt.plot(x, y, "o-")
plt.xlabel("x")  
plt.ylabel("y")  
plt.title("Метод Ейлера")  
plt.grid()  
plt.show()
# Out:
# x = [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# y = [0.6        0.67248399 0.75762869 0.85587461 0.96766238 1.09342661
#  1.23358781 1.388542   1.55864768 1.74421009 1.94546247]

# %%
#Розв’язок диф. Рівняння за допомогою scipy.integrate import odeint 
import numpy as np 
from scipy.integrate import odeint 
import matplotlib.pyplot as plt 

a = 0.5 # ліва межа відрізку 
b = 1.5 # права межа відрізку 
h = 0.1 # крок 

# function that returns dy/dx 
def model(y,x):  
    return x + np.sin(y/np.sqrt(7)) 
y0 = 0.6 

# x points 
x = np.linspace(a, b, n+1) # задаємо x 
# solve ODE 
y = odeint(model,y0,x) 
print('x=', x) 
print('y=',y) 

plt.plot(x, y, "o-")
plt.xlabel('x') 
plt.ylabel('y') 
plt.title('Розв’язання диф. рівняння') 
plt.grid()  
plt.show()
# Out:
# x= [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# y= [[0.6       ]
#  [0.67889392]
#  [0.77090927]
#  [0.87649838]
#  [0.99610819]
#  [1.13017168]
#  [1.27909723]
#  [1.443255  ]
#  [1.62296035]
#  [1.81845456]
#  [2.02988238]]

# %%
import numpy as np 
import matplotlib.pyplot as plt  

def f(x, y): 
    return x + np.cos(y/np.e)

a = 1.4 # ліва межа відрізку 
b = 2.4 # права межа відрізку 
h = 0.1 # крок 
y0 = 2.5 # початкова умова
n = int((b - a) / h) # кількість кроків 

x = np.linspace(a, b, n+1) # задаємо x 
y = np.zeros(n+1)
y[0] = y0 

for i in range(n): 
    y[i+1]=y[i]+(f(x[i],y[i])+f(x[i+1],y[i])+h*f(x[i],y[i]))*h/2

print("x =", x, "\ny =", y)

plt.plot(x, y, "o-")
plt.xlabel("x")  
plt.ylabel("y")  
plt.title("Метод Ейлера-Коші")  
plt.grid()  
plt.show()
# Out:
# x = [1.4 1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# y = [2.5        2.71563629 2.934954   3.1574704  3.38275001 3.61041195
#  3.84013581 4.07166613 4.30481533 4.53946541 4.77556861]

# %%
#Розв’язок диф. Рівняння за допомогою scipy.integrate import odeint 
import numpy as np 
from scipy.integrate import odeint 
import matplotlib.pyplot as plt 

a = 1.4 # ліва межа відрізку 
b = 2.4 # права межа відрізку 
h = 0.1 # крок 

# function that returns dy/dx 
def model(y,x):  
    return x + np.cos(y/np.e) 
y0 = 2.5 

# x points 
x = np.linspace(a, b, n+1) # задаємо x 
# solve ODE 
y = odeint(model,y0,x) 
print('x=', x) 
print('y=',y) 

plt.plot(x, y, "o-")
plt.xlabel('x') 
plt.ylabel('y') 
plt.title('Розв’язання диф. рівняння') 
plt.grid()  
plt.show()
# Out:
# x= [1.4 1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# y= [[2.5       ]
#  [2.70259694]
#  [2.9088891 ]
#  [3.11847171]
#  [3.33097829]
#  [3.54608619]
#  [3.7635211 ]
#  [3.98306076]
#  [4.20453734]
#  [4.42783931]
#  [4.65291247]]
